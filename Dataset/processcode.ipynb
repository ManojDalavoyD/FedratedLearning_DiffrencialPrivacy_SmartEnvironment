# %%
import pandas as pd

# %%
#load excel
df = pd.read_excel("D:/final_year_Project_M/Dataset/smart_home_power_consumption_400_homes.xlsx")
print(df.head())
# Out:
#   Unnamed: 0    h1    h2    h3    h4    h5   h6    h7    h8    h9  ...  h391  \
# 0       home  2699   279  1121  1035    70  397  1351  2217  2031  ...  2909
# 1  smart_fan  2222  2972  2776   961   531  656  1880   128  1331  ...  2395
# 2         ac  2631  2436  2940  1721  2474  737  1667  2856  1945  ...  2037
# 3   smart_tv  2751   549  2986  1001  1994  923  1614  2709  2615  ...  2129
# 4     fridge   935   617  2223   653  2363  176  1729   792   639  ...  2456
#
#    h392  h393  h394  h395  h396  h397  h398  h399  h400
# 0  1473  1797  1359   415   242  2623   967  2446  1346
# 1  1720  1306  1044   108  1845  2239  2989  2761  1526
# 2  2437  2336   780  2968  2911  2056  2657   214    59
# 3  2750  2023  2623  2198  2983  1793   439  2106   990
# 4  2651  1143   817  1880   936  2350  2115  1496  2515
#
# [5 rows x 401 columns]

# %%
#comands to convert row to col , col to row
df_transposed = df.transpose()
print(df_transposed.head())
# Out:
#               0          1     2         3       4       5                6   \
# Unnamed: 0  home  smart_fan    ac  smart_tv  fridge  lights  washing_machine
# h1          2699       2222  2631      2751     935    2652             1246
# h2           279       2972  2436       549     617    1384             2948
# h3          1121       2776  2940      2986    2223    1878             1631
# h4          1035        961  1721      1001     653     458              425
#
#               7               8       9       10
# Unnamed: 0  oven  electric_stove  heater  cooler
# h1          2826            2341    1138    2080
# h2          1774             631     240    2971
# h3          2873             596    2186    2480
# h4           772            1336     271     167

# %%
#convert to csv
df_transposed.to_csv("D:/final_year_Project_M/Dataset/smart_home_power_consumption_400_homes_transposed.csv", index=False)
